# %% [markdown]
# # Business Understanding

# %% [markdown]
# Een gameontwikkelaar heeft ons gevraagd om te kijken wat de beste eigenschappen van een game zijn, om zo zelf een succesvolle game te kunnen maken voor de app store. Om dit makkelijker te kunnen onderzoeken, hebben we de hoofdvraag in meerdere deelvragen opgesplitst.
#
# #### Hoofdvraag:
# "Wat zijn de meest belangrijke kenmerken van games met meer dan 1 miljoen downloads?"
#
# #### Deelvragen:
# "Is er een trend in het releasejaar en gemiddelde prijs van games?"
#
# "Wat is het aantal games per jaar gereleased?"
#
# "Zit er een relatie tussen het aantal ratings en de lifetime van een game (release  tot laatste update)"
#
# "Zit er een relatie tussen de extra genres en in-app aankopen?"
#
# "Maakt grootte uit voor de ratings van de game?"
#
# "Maakt het aantal games gereleased door de developer uit voor de ratings?"
#
# "Welke taal krijgt de hoogste reviews?"
#
# "Wat hebben de apps zonder rating gemeen?"
#
#
#
# #### Yorben:
# Trend in jaar en gemiddelde prijs & ratings en lifetime van een game

# %% [markdown]
# # Data Understanding

# %% [markdown]
# * de dataset die er wordt toegeleverd is een bestand in csv formaat.
# * de databron is makkelijk te benaderen vanuit python met behulp van pandas
# * de databse bevat 17007 rijen en 18 kolommen
# * de volgende kollommen staan in de database
#     * `URL`: de url naar de game in de appstore
#     * `ID`: unieke id voor de game
#     * `name`: naam van de app
#     * `subtitle`: alternative naam voor de app
#     * `icon url`: url naar de icon van de app
#     * `Avegage user rating`: de gemiddelde score van de app op de appstore
#     * `Uer rating count`: het aantal ratings dat de app heeft
#     * `price`: de aankoop prijs van de app
#     * `In-app Purchases`: lijst met prijzen van in-app aankopen
#     * `Description`: een omschrijving van de app
#     * `Developper`: de uitgever van de app
#     * `Age rating`: de aanbevolen minimumleeftijd (4+, 12+ ect.)
#     * `Languages`: talen waarin de app beschikbaar is
#     * `Size`: de groote van de app in bytes
#     * `primary` Genre: de genre van de app (entertainment, strategie, ect.)
#     * `Genres`: een lijst met overige genres waar binnen de app valt
#     * `Original` realease date: de datum waarop de app werd uitgegeven
#     * `current version release date`: de datum van de laatste update

# %% [markdown]
# #### Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans

# %config IPCompleter.greedy = True  
# %matplotlib inline

# %%
game_data = pd.read_csv("appstore_games.csv")

# %% [markdown]
# De data is ons gegeven in een excel bestand genaamd "appstore_games.csv".
#
# #### Bovenste rijen:

# %%
game_data.head()
# Out:
#                                                  URL         ID  \
# 0   https://apps.apple.com/us/app/sudoku/id284921427  284921427
# 1  https://apps.apple.com/us/app/reversi/id284926400  284926400
# 2  https://apps.apple.com/us/app/morocco/id284946595  284946595
# 3  https://apps.apple.com/us/app/sudoku-free/id28...  285755462
# 4  https://apps.apple.com/us/app/senet-deluxe/id2...  285831220
#
#             Name Subtitle                                           Icon URL  \
# 0         Sudoku      NaN  https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# 1        Reversi      NaN  https://is4-ssl.mzstatic.com/image/thumb/Purpl...
# 2        Morocco      NaN  https://is5-ssl.mzstatic.com/image/thumb/Purpl...
# 3  Sudoku (Free)      NaN  https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 4   Senet Deluxe      NaN  https://is1-ssl.mzstatic.com/image/thumb/Purpl...
#
#    Average User Rating  User Rating Count  Price In-app Purchases  \
# 0                  4.0             3553.0   2.99              NaN
# 1                  3.5              284.0   1.99              NaN
# 2                  3.0             8376.0   0.00              NaN
# 3                  3.5           190394.0   0.00              NaN
# 4                  3.5               28.0   2.99              NaN
#
#                                          Description  \
# 0  Join over 21,000,000 of our fans and download ...
# 1  The classic game of Reversi, also known as Oth...
# 2  Play the classic strategy game Othello (also k...
# 3  Top 100 free app for over a year.\nRated "Best...
# 4  "Senet Deluxe - The Ancient Game of Life and A...
#
#                   Developer Age Rating  \
# 0  Mighty Mighty Good Games         4+
# 1          Kiss The Machine         4+
# 2               Bayou Games         4+
# 3  Mighty Mighty Good Games         4+
# 4           RoGame Software         4+
#
#                                            Languages        Size  \
# 0  DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...  15853568.0
# 1                                                 EN  12328960.0
# 2                                                 EN    674816.0
# 3  DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...  21552128.0
# 4  DA, NL, EN, FR, DE, EL, IT, JA, KO, NO, PT, RU...  34689024.0
#
#   Primary Genre                             Genres Original Release Date  \
# 0         Games            Games, Strategy, Puzzle            11/07/2008
# 1         Games             Games, Strategy, Board            11/07/2008
# 2         Games             Games, Board, Strategy            11/07/2008
# 3         Games            Games, Strategy, Puzzle            23/07/2008
# 4         Games  Games, Strategy, Board, Education            18/07/2008
#
#   Current Version Release Date
# 0                   30/05/2017
# 1                   17/05/2018
# 2                    5/09/2017
# 3                   30/05/2017
# 4                   22/07/2018

# %% [markdown]
# #### Grootte

# %%
print("Aantal Rijen: " + str(game_data.shape[0]))
# Out:
# Aantal Rijen: 17007

# %% [markdown]
# #### Kolommen

# %%
game_data.columns
# Out:
# Index(['URL', 'ID', 'Name', 'Subtitle', 'Icon URL', 'Average User Rating',
#        'User Rating Count', 'Price', 'In-app Purchases', 'Description',
#        'Developer', 'Age Rating', 'Languages', 'Size', 'Primary Genre',
#        'Genres', 'Original Release Date', 'Current Version Release Date'],
#       dtype='object')

# %% [markdown]
# #### Types

# %%
game_data.dtypes
# Out:
# URL                              object
# ID                                int64
# Name                             object
# Subtitle                         object
# Icon URL                         object
# Average User Rating             float64
# User Rating Count               float64
# Price                           float64
# In-app Purchases                 object
# Description                      object
# Developer                        object
# Age Rating                       object
# Languages                        object
# Size                            float64
# Primary Genre                    object
# Genres                           object
# Original Release Date            object
# Current Version Release Date     object
# dtype: object

# %% [markdown]
# #### Lege velden?

# %%
game_data.isna().sum()
# Out:
# URL                              0
# ID                               0
# Name                             0
# Subtitle                         0
# Icon URL                         0
# Average User Rating              0
# User Rating Count                0
# Price                            0
# In-app Purchases                 0
# Description                      0
# Developer                        0
# Age Rating                       0
# Languages                        0
# Size                             1
# Primary Genre                    0
# Genres                           0
# Original Release Date            0
# Current Version Release Date     0
# release_year                     0
# lifetime                         0
# Description Length               0
# Amount of Languages              0
# lifetime_in_years                0
# Amount of Games per Developer    0
# StartOfDev                       0
# EndOfDev                         0
# DeveloperLifetime                0
# HasRating                        0
# dtype: int64

# %% [markdown]
# #### Eigenschappen?

# %%
game_data.describe().transpose()
# Out:
#                        count          mean           std          min  \
# ID                   17007.0  1.059614e+09  2.999676e+08  284921427.0
# Average User Rating   7561.0  4.060905e+00  7.514275e-01          1.0
# User Rating Count     7561.0  3.306531e+03  4.232256e+04          5.0
# Price                16983.0  8.134187e-01  7.835732e+00          0.0
# Size                 17006.0  1.157064e+08  2.036477e+08      51328.0
#
#                              25%           50%           75%           max
# ID                   899654330.0  1.112286e+09  1.286983e+09  1.475077e+09
# Average User Rating          3.5  4.500000e+00  4.500000e+00  5.000000e+00
# User Rating Count           12.0  4.600000e+01  3.090000e+02  3.032734e+06
# Price                        0.0  0.000000e+00  0.000000e+00  1.799900e+02
# Size                  22950144.0  5.676895e+07  1.330271e+08  4.005591e+09

# %% [markdown]
# # Data Preparation

# %% [markdown]
# #### Veld types goed maken en toevoegen

# %%
game_data["Original Release Date"] = pd.to_datetime(game_data["Original Release Date"])
game_data["Current Version Release Date"] = pd.to_datetime(game_data["Current Version Release Date"])
game_data["Age Rating"] = game_data["Age Rating"].astype("category")

game_data["release_year"] = game_data["Original Release Date"].dt.year
game_data["lifetime"] = game_data["Current Version Release Date"] - game_data["Original Release Date"]
game_data["Description Length"] = game_data["Description"].agg(len)

game_data["Languages"] = game_data["Languages"].fillna('')
game_data["Amount of Languages"] = game_data["Languages"].agg(len)

game_data["lifetime_in_years"] = (game_data["lifetime"].dt.days / 365).agg(round)

game_data["Amount of Languages"]
# Out:
# 0        66
# 1         2
# 2         2
# 3        66
# 4        58
#          ..
# 17002     2
# 17003     2
# 17004     2
# 17005     2
# 17006     6
# Name: Amount of Languages, Length: 17007, dtype: int64

# %%
per_dev = game_data["Developer"].value_counts().to_dict()

game_data["Amount of Games per Developer"] = game_data["Developer"].map(per_dev)
game_data["Amount of Games per Developer"]
game_data[game_data["Developer"] == "EBSolutions"].transpose()
# Out:
#                                                                             4520
# URL                            https://apps.apple.com/us/app/dark-holes/id912...
# ID                                                                     912843351
# Name                                                                  Dark Holes
# Subtitle
# Icon URL                       https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# Average User Rating                                                          0.0
# User Rating Count                                                            0.0
# Price                                                                        0.0
# In-app Purchases                                                      0.99, 0.99
# Description                    Save the universe. An alien invasion attacks t...
# Developer                                                            EBSolutions
# Age Rating                                                                    4+
# Languages                                                                     EN
# Size                                                                  37465088.0
# Primary Genre                                                              Games
# Genres                                    Games, Entertainment, Strategy, Action
# Original Release Date                                        2017-12-01 00:00:00
# Current Version Release Date                                 2017-01-16 00:00:00
# release_year                                                                2017
# lifetime                                                     -319 days +00:00:00
# Description Length                                                           458
# Amount of Languages                                                            2
# lifetime_in_years                                                             -1
# Amount of Games per Developer                                                  1
# StartOfDev                                                   2017-12-01 00:00:00
# EndOfDev                                                     2017-01-16 00:00:00
# DeveloperLifetime                                                           -319
# HasRating                                                                      0

# %%
def GetTimeOfDeveloper(column, first):
    groupedperdev = game_data.sort_values(column).set_index("Developer").groupby("Developer")[column]
    startofdev = groupedperdev.unique().map(lambda x : x[first]).to_dict()
    return game_data["Developer"].map(startofdev)

game_data["StartOfDev"] = GetTimeOfDeveloper("Original Release Date", 0)
game_data["EndOfDev"] = GetTimeOfDeveloper("Current Version Release Date", -1)
game_data["DeveloperLifetime"] = game_data["EndOfDev"] - game_data["StartOfDev"]
game_data["DeveloperLifetime"] = pd.Series([x.days for x in game_data["DeveloperLifetime"]]).agg(abs)
game_data[["Developer","DeveloperLifetime"]].sort_values("DeveloperLifetime")
# Out:
#              Developer  DeveloperLifetime
# 17006     ming bo tang                  0
# 5360     Offline games                  0
# 14279  Vsevolod Azarov                  0
# 5386          Mobirate                  0
# 5393          jan borg                  0
# ...                ...                ...
# 115       Tom Kerrigan               4071
# 36        Tom Kerrigan               4071
# 33        Tom Kerrigan               4071
# 116       Tom Kerrigan               4071
# 40     Spiffcode, Inc.               4086
#
# [17007 rows x 2 columns]

# %%
hasrating = game_data["User Rating Count"]>0
game_data["HasRating"] = hasrating.astype("int")

# %% [markdown]
# #### Lege velden invullen of weghalen

# %%
game_data["Price"] = game_data["Price"].fillna(0)
game_data["Subtitle"] = game_data["Subtitle"].fillna('')
game_data["Average User Rating"] = game_data["Average User Rating"].fillna(0)
game_data["User Rating Count"] = game_data["User Rating Count"].fillna(0)
game_data["Size"] = game_data["Size"].fillna(0)
game_data["In-app Purchases"] = game_data["In-app Purchases"].fillna('')

# %% [markdown]
# #### Data normalizeren

# %%
normalizedData = game_data.copy()
normalizedData = normalizedData[["Average User Rating","User Rating Count","Price","Size"]]
normalizedData = (normalizedData - normalizedData.min()) / (normalizedData.max() - normalizedData.min())
normalizedData["Age Rating"] = game_data["Age Rating"]
sns.set_context("poster")

g = sns.pairplot(game_data, hue="Age Rating")
for ax in g.axes.flatten():
    # rotate x axis labels
    ax.set_xlabel(ax.get_xlabel(), rotation = 90)
    # rotate y axis labels
    ax.set_ylabel(ax.get_ylabel(), rotation =0)
    ax.yaxis.get_label().set_horizontalalignment('right')

# %%
sns.relplot(y='Size',x='Average User Rating', data = game_data, 
            col = 'Age Rating', col_order=["4+","9+","12+","17+"],
            kind='line', 
            hue='Age Rating', 
            ci=None,
            row='release_year')

# %%
sns.heatmap(game_data.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
sns.violinplot(x="Age Rating",y="Average User Rating",data=game_data, order=["4+","9+","12+","17+"])
# Out:
# <AxesSubplot:xlabel='Age Rating', ylabel='Average User Rating'>

# %% [markdown]
# # Modeling

# %% [markdown]
# #### Groeperen en gemiddelde berekenen

# %%
grouped = game_data[game_data["Price"] > 0].set_index("release_year").sort_index().reset_index().groupby("release_year")
peryear = pd.DataFrame(grouped["Price"].mean())
peryear2 = pd.DataFrame(grouped["Price"].median())
ax = sns.lineplot(data = peryear, x = "release_year", y = "Price")
ax = sns.lineplot(data = peryear2, x = "release_year", y = "Price")
ax.set(title='Average price for games per year')
ax.set(xlabel="Release Year", ylabel = "Average Price")
# Out:
# [Text(0.5, 0, 'Release Year'), Text(0, 0.5, 'Average Price')]

# %%
groupedlifetime = game_data[game_data["Average User Rating"] > 0].set_index("lifetime_in_years").sort_index().reset_index().groupby("lifetime_in_years")
pertime = pd.DataFrame(groupedlifetime["Average User Rating"].mean())
ax = sns.lineplot(data = pertime, x = "lifetime_in_years", y = "Average User Rating")
ax.set(title='Average Rating per year of lifetime')
ax.set(xlabel="Lifetime in Years", ylabel = "Average Review Rating")
# Out:
# [Text(0.5, 0, 'Lifetime in Years'), Text(0, 0.5, 'Average Review Rating')]

# %%
game_data[game_data["Price"] < 100].sort_values("Price", ascending=False).head(15)
# Out:
#                                                      URL          ID  \
# 4846   https://apps.apple.com/us/app/arena-dodge/id93...   933223586
# 15031  https://apps.apple.com/us/app/goto-bridge-19/i...  1434393509
# 13730  https://apps.apple.com/us/app/blindfold-studen...  1350423680
# 14093  https://apps.apple.com/us/app/chess-openings-w...  1370631887
# 14281  https://apps.apple.com/us/app/strong-mind-esti...  1383404371
# 16421  https://apps.apple.com/us/app/maze-jam/id14588...  1458832763
# 2863   https://apps.apple.com/us/app/panzer-corps/id7...   736781904
# 276    https://apps.apple.com/us/app/smartgo-kifu/id3...   364854741
# 4609   https://apps.apple.com/us/app/battle-academy-2...   917359165
# 9162   https://apps.apple.com/us/app/spaceship-fighti...  1134849539
# 10130  https://apps.apple.com/us/app/cargo-crane-car-...  1170365893
# 16702  https://apps.apple.com/us/app/rp-baseball-play...  1466192445
# 10376  https://apps.apple.com/us/app/christmas-tree-c...  1180473088
# 3898   https://apps.apple.com/us/app/commander-the-gr...   880963492
# 4885   https://apps.apple.com/us/app/warhammer-40-000...   935248214
#
#                                                 Name  \
# 4846                                     Arena Dodge
# 15031                                 GOTO Bridge 19
# 13730                       Blindfold Student Pack 1
# 14093                          Chess Openings Wizard
# 14281                         Strong Mind Estimator!
# 16421                                       Maze Jam
# 2863                                    Panzer Corps
# 276                                     SmartGo Kifu
# 4609                 Battle Academy 2: Eastern Front
# 9162          Spaceship Fighting Battle Wars 3D Full
# 10130             Cargo Crane & Car Delivery 3D Full
# 16702                          RP BASEBALL - Play It
# 10376  Christmas Tree Construction Simulator 3D Full
# 3898                         Commander the Great War
# 4885                    Warhammer 40,000: Armageddon
#
#                              Subtitle  \
# 4846                              NaN
# 15031       The must-have bridge game
# 13730               Navigation Skills
# 14093          Build 43 companion app
# 14281  Refine your estimation skills!
# 16421           Jam Packed with Mazes
# 2863                              NaN
# 276      The premier tool to study Go
# 4609                              NaN
# 9162                              NaN
# 10130                             NaN
# 16702      Play against your friends.
# 10376                             NaN
# 3898                              NaN
# 4885                              NaN
#
#                                                 Icon URL  Average User Rating  \
# 4846   https://is4-ssl.mzstatic.com/image/thumb/Purpl...                  NaN
# 15031  https://is3-ssl.mzstatic.com/image/thumb/Purpl...                  4.0
# 13730  https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  NaN
# 14093  https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  4.0
# 14281  https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  NaN
# 16421  https://is3-ssl.mzstatic.com/image/thumb/Purpl...                  NaN
# 2863   https://is4-ssl.mzstatic.com/image/thumb/Purpl...                  4.5
# 276    https://is4-ssl.mzstatic.com/image/thumb/Purpl...                  4.5
# 4609   https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  4.0
# 9162   https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  NaN
# 10130  https://is4-ssl.mzstatic.com/image/thumb/Purpl...                  NaN
# 16702  https://is2-ssl.mzstatic.com/image/thumb/Purpl...                  NaN
# 10376  https://is3-ssl.mzstatic.com/image/thumb/Purpl...                  NaN
# 3898   https://is4-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# 4885   https://is4-ssl.mzstatic.com/image/thumb/Purpl...                  4.0
#
#        User Rating Count  Price  \
# 4846                 NaN  99.99
# 15031               50.0  59.99
# 13730                NaN  37.99
# 14093                9.0  36.99
# 14281                NaN  29.99
# 16421                NaN  29.99
# 2863               249.0  19.99
# 276                227.0  19.99
# 4609                83.0  19.99
# 9162                 NaN  19.99
# 10130                NaN  19.99
# 16702                NaN  19.99
# 10376                NaN  19.99
# 3898                98.0  19.99
# 4885                72.0  19.99
#
#                                         In-app Purchases  \
# 4846                                                 NaN
# 15031                                                NaN
# 13730                                                NaN
# 14093                                                NaN
# 14281                                                NaN
# 16421                                                NaN
# 2863   14.99, 59.99, 9.99, 14.99, 4.99, 14.99, 4.99, ...
# 276                                                  NaN
# 4609                                                9.99
# 9162                                                 NaN
# 10130                                                NaN
# 16702                      0.99, 1.99, 4.99, 9.99, 14.99
# 10376                                                NaN
# 3898                                                 NaN
# 4885                  9.99, 4.99, 4.99, 4.99, 4.99, 4.99
#
#                                              Description  ... release_year  \
# 4846   Contained within the Arena.\nGet millions of p...  ...         2014
# 15031  Discover the 19th edition of GOTO Bridge, the ...  ...         2018
# 13730  "Blindfold Student Pack 1: Navigation skills i...  ...         2018
# 14093  "Chess Openings Wizard is where tournament pla...  ...         2018
# 14281  Strong Mind Estimator presents mathematical pu...  ...         2019
# 16421  Play artistically handcrafted, unusually brill...  ...         2019
# 2863   Panzer Corps has been hailed as the \u201cthe ...  ...         2013
# 276    "SmartGo Kifu transforms your iPad into a Go b...  ...         2010
# 4609   This is a 32 bit app. You will always be able ...  ...         2014
# 9162   Join space battles, shoot the enemies, collect...  ...         2016
# 10130  Explore sea ports, manage your own small deliv...  ...         2016
# 16702  Ever find yourself watching a baseball game an...  ...         2019
# 10376  Christmas is coming! Become a city constructio...  ...         2016
# 3898   This is a 32 bit app. You will always be able ...  ...         2014
# 4885   ARMAGEDDON MUST NOT BE LOST\n\nAvailable in En...  ...         2015
#
#        lifetime Description Length  Amount of Languages lifetime_in_years  \
# 4846     0 days                592                    2                 0
# 15031   33 days               2908                    6                 0
# 13730    2 days               2154                    2                 0
# 14093    0 days               1130                    2                 0
# 14281    0 days                998                    2                 0
# 16421    0 days               1184                    2                 0
# 2863   968 days               3361                    2                 3
# 276   3390 days               1359                   34                 9
# 4609   104 days               1740                    2                 0
# 9162     0 days               1286                    2                 0
# 10130    0 days               1162                    2                 0
# 16702    0 days               1183                    2                 0
# 10376    0 days               1247                    2                 0
# 3898   254 days               2348                    2                 1
# 4885   535 days               3879                    2                 1
#
#       Amount of Games per Developer StartOfDev   EndOfDev  DeveloperLifetime  \
# 4846                              1 2014-03-11 2014-03-11                  0
# 15031                             6 2010-12-22 2019-07-17               3129
# 13730                            15 2015-01-07 2019-07-31               1666
# 14093                             1 2018-12-22 2018-12-22                  0
# 14281                             1 2019-06-04 2019-06-04                  0
# 16421                             1 2019-04-17 2019-04-17                  0
# 2863                             20 2012-12-13 2019-03-20               2288
# 276                               4 2009-06-05 2019-04-19               3605
# 4609                             20 2012-12-13 2019-03-20               2288
# 9162                             37 2016-01-11 2017-10-03                631
# 10130                            37 2016-01-11 2017-10-03                631
# 16702                             1 2019-03-08 2019-03-08                  0
# 10376                            37 2016-01-11 2017-10-03                631
# 3898                             20 2012-12-13 2019-03-20               2288
# 4885                             20 2012-12-13 2019-03-20               2288
#
#       HasRating
# 4846          0
# 15031         1
# 13730         0
# 14093         1
# 14281         0
# 16421         0
# 2863          1
# 276           1
# 4609          1
# 9162          0
# 10130         0
# 16702         0
# 10376         0
# 3898          1
# 4885          1
#
# [15 rows x 28 columns]

# %% [markdown]
# ## Scraper Test

# %%
from itunes_app_scraper.scraper import AppStoreScraper
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1380/194315842.py in <module>
# ----> 1 from itunes_app_scraper.scraper import AppStoreScraper
#       2 import pandas as pd
#
# ModuleNotFoundError: No module named 'itunes_app_scraper'

# %%
scraper = AppStoreScraper()

# %%
app_store_list = list(scraper.get_multiple_app_details([1318382054]))

# %%
df = pd.DataFrame(app_store_list)

# %%
df.columns
